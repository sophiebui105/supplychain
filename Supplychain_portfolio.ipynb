# %%
# @title Văn bản tiêu đề mặc định
import pandas as pd
data = pd.read_csv("/content/DataCoSupplyChainDataset.csv", encoding='latin-1')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data.shape
# Out:
# (180519, 53)

# %%
print(data.columns)
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
data.dtypes
# Out:
# Type                              object
# Days for shipping (real)           int64
# Days for shipment (scheduled)      int64
# Benefit per order                float64
# Sales per customer               float64
# Delivery Status                   object
# Late_delivery_risk                 int64
# Category Id                        int64
# Category Name                     object
# Customer City                     object
# Customer Country                  object
# Customer Email                    object
# Customer Fname                    object
# Customer Id                        int64
# Customer Lname                    object
# Customer Password                 object
# Customer Segment                  object
# Customer State                    object
# Customer Street                   object
# Customer Zipcode                 float64
# Department Id                      int64
# Department Name                   object
# Latitude                         float64
# ...

# %%
train_data = data[0:68410]

# %%
train_data.shape
# Out:
# (68410, 53)

# %%
train_data.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
test_data = data[68410:85513]

# %%
test_data.shape
# Out:
# (17103, 53)

# %%
dups = train_data.duplicated().sum()
dups
# Out:
# 0

# %%
dups = test_data.duplicated().sum()
dups
# Out:
# 0

# %%
def missing(df):
  """
  For each attribute/column in the dataframe `df`, count the number of missing entries.
  Return a list of all the coulmns with more than 80% missing entries.
  """
  missing_dict = dict()
  total = df.shape[0] # shape[0] is the number of rows
  for attribute in df.columns:
    missing = df[attribute].isna().sum() # count the number of Null/nan/na values
    frac = missing/total * 100 # as a percentage
    missing_dict[attribute] = frac
  return missing_dict

# %%
m_dict_train = missing(train_data)
m_dict_train
# Out:
# {'Type': 0.0,
#  'Days for shipping (real)': 0.0,
#  'Days for shipment (scheduled)': 0.0,
#  'Benefit per order': 0.0,
#  'Sales per customer': 0.0,
#  'Delivery Status': 0.0,
#  'Late_delivery_risk': 0.0,
#  'Category Id': 0.0,
#  'Category Name': 0.0,
#  'Customer City': 0.0,
#  'Customer Country': 0.0,
#  'Customer Email': 0.0,
#  'Customer Fname': 0.0,
#  'Customer Id': 0.0,
#  'Customer Lname': 0.0029235491887151,
#  'Customer Password': 0.0,
#  'Customer Segment': 0.0,
#  'Customer State': 0.0,
#  'Customer Street': 0.0,
#  'Customer Zipcode': 0.0029235491887151,
#  'Department Id': 0.0,
#  'Department Name': 0.0,
#  'Latitude': 0.0,
#  'Longitude': 0.0,
#  'Market': 0.0,
#  'Order City': 0.0,
#  'Order Country': 0.0,
#  'Order Customer Id': 0.0,
#  'order date (DateOrders)': 0.0,
#  'Order Id': 0.0,
#  'Order Item Cardprod Id': 0.0,
#  'Order Item Discount': 0.0,
#  'Order Item Discount Rate': 0.0,
#  'Order Item Id': 0.0,
#  'Order Item Product Price': 0.0,
# ...

# %%
m_dict_test = missing(test_data)
m_dict_test
# Out:
# {'Type': 0.0,
#  'Days for shipping (real)': 0.0,
#  'Days for shipment (scheduled)': 0.0,
#  'Benefit per order': 0.0,
#  'Sales per customer': 0.0,
#  'Delivery Status': 0.0,
#  'Late_delivery_risk': 0.0,
#  'Category Id': 0.0,
#  'Category Name': 0.0,
#  'Customer City': 0.0,
#  'Customer Country': 0.0,
#  'Customer Email': 0.0,
#  'Customer Fname': 0.0,
#  'Customer Id': 0.0,
#  'Customer Lname': 0.0,
#  'Customer Password': 0.0,
#  'Customer Segment': 0.0,
#  'Customer State': 0.0,
#  'Customer Street': 0.0,
#  'Customer Zipcode': 0.005846927439630474,
#  'Department Id': 0.0,
#  'Department Name': 0.0,
#  'Latitude': 0.0,
#  'Longitude': 0.0,
#  'Market': 0.0,
#  'Order City': 0.0,
#  'Order Country': 0.0,
#  'Order Customer Id': 0.0,
#  'order date (DateOrders)': 0.0,
#  'Order Id': 0.0,
#  'Order Item Cardprod Id': 0.0,
#  'Order Item Discount': 0.0,
#  'Order Item Discount Rate': 0.0,
#  'Order Item Id': 0.0,
#  'Order Item Product Price': 0.0,
# ...

# %%
cols_to_drop = [ att for att,frac in m_dict_train.items() if frac >80]
cols_to_drop
# Out:
# ['Order Zipcode', 'Product Description']

# %%
cols_to_drop = [ att for att,frac in m_dict_test.items() if frac >80]
cols_to_drop
# Out:
# ['Order Zipcode', 'Product Description']

# %%
cols_to_drop = ['Order Zipcode', 'Product Description']
train_data.drop(columns=cols_to_drop,
           inplace=True)
# Out:
# <ipython-input-206-2d3f99b7422d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.drop(columns=cols_to_drop,

# %%
cols_to_drop = ['Order Zipcode', 'Product Description']
test_data.drop(columns=cols_to_drop,
           inplace=True)
# Out:
# <ipython-input-207-4f661a0108d1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.drop(columns=cols_to_drop,

# %%
data['order date (DateOrders)'] = pd.to_datetime(data['order date (DateOrders)'])
data['shipping date (DateOrders)'] = pd.to_datetime(data['shipping date (DateOrders)'])

# %%
data['delivery_days'] = data['shipping date (DateOrders)'] - data['order date (DateOrders)']

# %%
print(data[['order date (DateOrders)', 'shipping date (DateOrders)', 'delivery_days']].head())
# Out:
#   order date (DateOrders) shipping date (DateOrders) delivery_days
# 0     2018-01-31 22:56:00        2018-02-03 22:56:00        3 days
# 1     2018-01-13 12:27:00        2018-01-18 12:27:00        5 days
# 2     2018-01-13 12:06:00        2018-01-17 12:06:00        4 days
# 3     2018-01-13 11:45:00        2018-01-16 11:45:00        3 days
# 4     2018-01-13 11:24:00        2018-01-15 11:24:00        2 days

# %%
# # @title Label Encoding & One-Hot Encoding
# from sklearn.preprocessing import LabelEncoder
# from sklearn.preprocessing import OneHotEncoder

# cate = train_data[['Shipping Mode', 'Order Region', 'Delivery Status', 'Category Name', 'Customer City', 'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Lname', 'Customer Password', 'Customer Segment', 'Customer State', 'Customer Street', 'Department Name', 'Market', 'Order City', 'Order Country', 'order date (DateOrders)', 'Order State', 'Order Status', 'Product Image', 'Product Name', 'shipping date (DateOrders)']]
# le_dict ={}

# for col in cate.columns:
#     le = LabelEncoder()
#     cate[col] = le.fit_transform(cate[col])
#     le_dict[col] = le

# print(cate)
# Out:
# <ipython-input-211-43b54680b53f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cate[col] = le.fit_transform(cate[col])
# <ipython-input-211-43b54680b53f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cate[col] = le.fit_transform(cate[col])
# <ipython-input-211-43b54680b53f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# from sklearn.preprocessing import LabelEncoder
# from sklearn.preprocessing import OneHotEncoder

# cate = test_data[['Shipping Mode', 'Order Region', 'Delivery Status', 'Category Name', 'Customer City', 'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Lname', 'Customer Password', 'Customer Segment', 'Customer State', 'Customer Street', 'Department Name', 'Market', 'Order City', 'Order Country', 'order date (DateOrders)', 'Order State', 'Order Status', 'Product Image', 'Product Name', 'shipping date (DateOrders)']]
# le_dict ={}

# for col in cate.columns:
#     le = LabelEncoder()
#     cate[col] = le.fit_transform(cate[col])
#     le_dict[col] = le

# print(cate)
# Out:
# <ipython-input-212-ffe0ea39d7c1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cate[col] = le.fit_transform(cate[col])
# <ipython-input-212-ffe0ea39d7c1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cate[col] = le.fit_transform(cate[col])
# <ipython-input-212-ffe0ea39d7c1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# numeric_attributes_train = train_data.select_dtypes(include='number').columns
# numeric_attributes_train
# Out:
# Index(['Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Late_delivery_risk',
#        'Category Id', 'Customer Id', 'Customer Zipcode', 'Department Id',
#        'Latitude', 'Longitude', 'Order Customer Id', 'Order Id',
#        'Order Item Cardprod Id', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity', 'Sales',
#        'Order Item Total', 'Order Profit Per Order', 'Product Card Id',
#        'Product Category Id', 'Product Price', 'Product Status'],
#       dtype='object')

# %%
# numeric_attributes_test = test_data.select_dtypes(include='number').columns
# numeric_attributes_test
# Out:
# Index(['Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Late_delivery_risk',
#        'Category Id', 'Customer Id', 'Customer Zipcode', 'Department Id',
#        'Latitude', 'Longitude', 'Order Customer Id', 'Order Id',
#        'Order Item Cardprod Id', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity', 'Sales',
#        'Order Item Total', 'Order Profit Per Order', 'Product Card Id',
#        'Product Category Id', 'Product Price', 'Product Status'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
summary_stats = data[['Days for shipping (real)', 'Days for shipment (scheduled)']].describe()
print(summary_stats)
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(data=data[['Days for shipping (real)', 'Days for shipment (scheduled)']])
plt.title("Boxplot of Shipping Days")
plt.ylabel("Days")
plt.show()

customer experiencing delays => needs optimization
Delivery Delays: Since actual shipping takes longer than planned, customers may be receiving orders later than promised.
Logistics Optimization Needed: The company should investigate reasons for the delays (e.g., supply chain inefficiencies, transportation issues).
Customer Satisfaction Risk: Longer and inconsistent shipping times can lead to poor customer experience and complaints.

# %%
train_data["Late_delivery"] = train_data["Days for shipping (real)"] - train_data["Days for shipment (scheduled)"]
print(train_data["Late_delivery"].head(20))
# Out:
# 0    -1
# 1     1
# 2     0
# 3    -1
# 4    -2
# 5     2
# 6     1
# 7     1
# 8     1
# 9     1
# 10    4
# 11    3
# 12    2
# 13    1
# 14    1
# 15    1
# 16    3
# 17    1
# 18    1
# 19    0
# Name: Late_delivery, dtype: int64
# <ipython-input-219-628ddeecc78b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data["Late_delivery"] = train_data["Days for shipping (real)"] - train_data["Days for shipment (scheduled)"]

# %%
test_data["Late_delivery"] = test_data["Days for shipping (real)"] - test_data["Days for shipment (scheduled)"]
print(test_data["Late_delivery"].head(20))
# Out:
# 68410   -2
# 68411    1
# 68412    2
# 68413    0
# 68414   -2
# 68415   -2
# 68416    1
# 68417   -2
# 68418    2
# 68419    1
# 68420    1
# 68421   -1
# 68422   -2
# 68423    0
# 68424    0
# 68425   -2
# 68426   -1
# 68427   -1
# 68428   -2
# 68429    1
# Name: Late_delivery, dtype: int64
# <ipython-input-220-515f04fdc17f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["Late_delivery"] = test_data["Days for shipping (real)"] - test_data["Days for shipment (scheduled)"]

# %%
late_by_shipping = train_data.groupby("Shipping Mode")["Late_delivery"].mean()
late_by_shipping.shape
# data.groupby("Category Name")["Days for shipping (real)"].mean()
# data.groupby("Order Region")["Days for shipping (real)"].mean()
# Out:
# (4,)

# %%
late_by_category = train_data.groupby("Category Name")["Late_delivery"].mean()
late_by_category.sort_values(ascending=False).head(5)
# Out:
# Category Name
# Soccer                 0.857143
# Crafts                 0.828571
# Basketball             0.821429
# Fitness Accessories    0.812950
# Boxing & MMA           0.812155
# Name: Late_delivery, dtype: float64

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x=late_by_shipping.index, y=late_by_shipping.values, palette="coolwarm")
plt.xlabel("Shipping Mode")
plt.ylabel("Late Delivery Rate")
plt.title("Late Delivery Rate by Shipping Mode")
plt.show()
# Out:
# <ipython-input-248-4686a739894b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=late_by_shipping.index, y=late_by_shipping.values, palette="coolwarm")

# %%
plt.figure(figsize=(8, 4))
sns.piechart(x=late_by_category.index, y=late_by_category.values, palette="coolwarm")
plt.xlabel("Shipping Mode")
plt.ylabel("Late Delivery Rate")
plt.title("Late Delivery Rate by Shipping Mode")
plt.show()
# Out:
# <ipython-input-249-8ef028355d61>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=late_by_category.index, y=late_by_category.values, palette="coolwarm")

# %%
train_data.groupby("Order Region")["Late_delivery"].mean()
# Out:
# Order Region
# Canada             0.460526
# Caribbean          0.597823
# Central Africa     0.649728
# Central America    0.598780
# Central Asia       0.768473
# East Africa        0.681431
# East of USA        0.672760
# Eastern Asia       0.646269
# Eastern Europe     0.633846
# North Africa       0.590373
# Northern Europe    0.621345
# Oceania            0.632597
# South America      0.592940
# South Asia         0.705660
# South of  USA      0.789593
# Southeast Asia     0.638044
# Southern Africa    0.486618
# Southern Europe    0.559282
# US Center          0.711325
# West Africa        0.567152
# West Asia          0.734119
# West of USA        0.657718
# Western Europe     0.629229
# Name: Late_delivery, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.histplot(train_data["Days for shipping (real)"], bins=20, kde=True, color='blue', label="Actual")
sns.histplot(train_data["Days for shipment (scheduled)"], bins=20, kde=True, color='orange', label="Scheduled")
plt.xlabel("Shipping Days")
plt.ylabel("Frequency")
plt.legend()
plt.title("Histogram of Shipping Days")
plt.show()

# %%
import folium
from folium.plugins import HeatMap

# Filter only late deliveries
late_deliveries = train_data[train_data["Late_delivery"] > 0]


# Create a map centered at an average location
m = folium.Map(location=[train_data["Latitude"].mean(), train_data["Longitude"].mean()], zoom_start=5)

# Add heatmap layer
heat_data = list(zip(late_deliveries["Latitude"], late_deliveries["Longitude"]))
HeatMap(heat_data).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numerical columns
numerical_columns = train_data.select_dtypes(include='number')

# Calculate correlation matrix
correlation_matrix = numerical_columns.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table_shipping = pd.crosstab(train_data['Shipping Mode'], train_data['Late_delivery'])

# Perform Chi-square test
chi2_ship, p_ship, dof, expected = chi2_contingency(contingency_table_shipping)
print("Chi-Square Test Statistic Ship:", chi2_ship)
print("p-value:", p_ship)
# Out:
# Chi-Square Test Statistic Ship: 58781.54225081206
# p-value: 0.0

# %%
# Create a contingency table
contingency_table_shipping = pd.crosstab(test_data['Shipping Mode'], test_data['Late_delivery'])

# Perform Chi-square test
chi2_ship, p_ship, dof, expected = chi2_contingency(contingency_table_shipping)
print("Chi-Square Test Statistic Ship:", chi2_ship)
print("p-value:", p_ship)
# Out:
# Chi-Square Test Statistic Ship: 14763.961011523776
# p-value: 0.0

# %%
# Create a contingency table
contingency_table_region = pd.crosstab(train_data['Order Region'], train_data['Late_delivery'])

chi2_region, p_region, dof, expected = chi2_contingency(contingency_table_region)
print("Chi-Square Test Statistic Region:", chi2_region)
print("p-value:", p_region)
# Out:
# Chi-Square Test Statistic Region: 433.8909865730899
# p-value: 7.6154270700154606e-34

# %%
contingency_table_region = pd.crosstab(test_data['Order Region'], test_data['Late_delivery'])

chi2_region, p_region, dof, expected = chi2_contingency(contingency_table_region)
print("Chi-Square Test Statistic Region:", chi2_region)
print("p-value:", p_region)
# Out:
# Chi-Square Test Statistic Region: 320.42173697965495
# p-value: 1.0788400807434938e-17

# %%
contingency_table_country = pd.crosstab(train_data['Order Country'], train_data['Late_delivery'])

chi2_country, p_country, dof, expected = chi2_contingency(contingency_table_country)
print("Chi-Square Test Statistic Country:", chi2_country)
print("p-value:", p_country)
# Out:
# Chi-Square Test Statistic Country: 2483.817677758047
# p-value: 1.0523800756075435e-141

# %%
contingency_table_country = pd.crosstab(test_data['Order Country'], test_data['Late_delivery'])

chi2_country, p_country, dof, expected = chi2_contingency(contingency_table_country)
print("Chi-Square Test Statistic Country:", chi2_country)
print("p-value:", p_country)
# Out:
# Chi-Square Test Statistic Country: 1465.713335580982
# p-value: 1.9773647211319353e-30

# %%
contingency_table_category = pd.crosstab(train_data['Category Name'], train_data['Late_delivery'])

chi2_category, p_category, dof, expected = chi2_contingency(contingency_table_category)
print("Chi-Square Test Statistic Category:", chi2_category)
print("p-value:", p_category)
# Out:
# Chi-Square Test Statistic Category: 362.96245543060274
# p-value: 0.0017808160040910198

# %%
train_data.groupby('Category Name')['Late_delivery'].mean().sort_values()
# Out:
# Category Name
# Men's Golf Clubs        0.325088
# As Seen on  TV!         0.384615
# Kids' Golf Clubs        0.460000
# Hockey                  0.469055
# Golf Apparel            0.473923
# Water Sports            0.522806
# Accessories             0.544010
# Computers               0.547170
# Toys                    0.551985
# Women's Golf Clubs      0.558011
# Golf Balls              0.572788
# Baby                    0.572917
# Golf Shoes              0.578244
# Men's Clothing          0.592105
# Cardio Equipment        0.593820
# Strength Training       0.608696
# Golf Gloves             0.615888
# DVDs                    0.617512
# Electronics             0.618627
# Sporting Goods          0.619048
# Children's Clothing     0.625442
# Women's Apparel         0.626296
# Lacrosse                0.626506
# Hunting & Shooting      0.630208
# Cleats                  0.632344
# Shop By Sport           0.638472
# Men's Footwear          0.653339
# Garden                  0.656566
# ...
